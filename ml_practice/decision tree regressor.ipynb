# %% [markdown]
# ## decision tree regressor

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(0, 10, 100)
y = np.sin(X) + np.random.normal(0, 0.1, size=X.shape[0])
Y = np.sin(X)
plt.subplot(2,1,1)
plt.scatter(X,y)
plt.subplot(2,1,2)
plt.scatter(X,Y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# Generate some random data for demonstration
np.random.seed(0)
X = np.linspace(0, 10, 100)
y = np.sin(X) + np.random.normal(0, 0.1, size=X.shape[0])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Reshape the data for compatibility with scikit-learn
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
print(X_test.shape)
# Out:
# (20, 1)

# %%
# Initialize and train the decision tree regressor
regressor = DecisionTreeRegressor(max_depth=5)
regressor.fit(X_train, y_train)

# Predict
y_pred_train = regressor.predict(X_train)
y_pred_test = regressor.predict(X_test)

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='red', label='Testing data')
plt.plot(X, regressor.predict(X.reshape(-1, 1)), color='green', label='Decision tree regressor')
plt.title('Decision Tree Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
from sklearn import tree 
tree.plot_tree(regressor,filled=True);

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
plt.figure(figsize=(30,5))
# Generate some random data for demonstration
np.random.seed(0)
X = np.linspace(0, 10, 100)
y = np.sin(X) + np.random.normal(0, 0.1, size=X.shape[0])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Reshape the data for compatibility with scikit-learn
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

# Initialize and train the decision tree regressor
regressor = DecisionTreeRegressor(max_depth=5)
regressor.fit(X_train, y_train)

# Plot the decision tree
plt.figure(figsize=(15, 10))
plot_tree(regressor, filled=True, feature_names=['X'], rounded=True, fontsize=8)


plt.title('Decision Tree Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
## decision tree regressor 

import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(0, 10, 100)
y = np.sin(X) + np.random.normal(0, 0.1, size=X.shape[0])
Y = np.sin(X)
plt.subplot(2,1,1)
plt.scatter(X,y)
plt.subplot(2,1,2)
plt.scatter(X,Y)

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# Generate some random data for demonstration
np.random.seed(0)
X = np.linspace(0, 10, 100)
y = np.sin(X) + np.random.normal(0, 0.1, size=X.shape[0])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Reshape the data for compatibility with scikit-learn
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
print(X_test.shape)

# Initialize and train the decision tree regressor
regressor = DecisionTreeRegressor(max_depth=5)
regressor.fit(X_train, y_train)

# Predict
y_pred_train = regressor.predict(X_train)
y_pred_test = regressor.predict(X_test)

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='red', label='Testing data')
plt.plot(X, regressor.predict(X.reshape(-1, 1)), color='green', label='Decision tree regressor')
plt.title('Decision Tree Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

from sklearn import tree 
tree.plot_tree(regressor,filled=True);

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
plt.figure(figsize=(30,5))
# Generate some random data for demonstration
np.random.seed(0)
X = np.linspace(0, 10, 100)
y = np.sin(X) + np.random.normal(0, 0.1, size=X.shape[0])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Reshape the data for compatibility with scikit-learn
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

# Initialize and train the decision tree regressor
regressor = DecisionTreeRegressor(max_depth=5)
regressor.fit(X_train, y_train)

# Plot the decision tree
plt.figure(figsize=(15, 10))
plot_tree(regressor, filled=True, feature_names=['X'], rounded=True, fontsize=8)


plt.title('Decision Tree Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
