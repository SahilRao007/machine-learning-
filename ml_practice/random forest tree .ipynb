# %%
import pandas as pd 
import numpy as np 
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt 
import seaborn as sns; sns.set_theme(style='darkgrid')

# %%
iris=load_iris()

# %%
data=iris.data
target=iris.target

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,target)

# %%
clf=RandomForestClassifier() #default is 100 sample trees

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print(clf.base_estimator_)
print(clf.classes_) #output classes 
print(clf.estimator_params)
# Out:
# DecisionTreeClassifier()
# [0 1 2]
# ('criterion', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'random_state', 'ccp_alpha')

# %%
y_pred=clf.predict(X_test)
clf.score(X_test,y_test)
# Out:
# 0.9736842105263158

# %%
from sklearn import tree

# %%
plt.figure(figsize=(11,5))
tree.plot_tree(clf.estimators_[1],filled=True); #2nd tree from random tree forest

# %%
#ploting first 5 trees
plt.figure(figsize=(10,30))
for i in range(5):
    plt.subplot(5,1,i+1)
    tree.plot_tree(clf.estimators_[i],filled=True)
    plt.title(f"Tree no {i+1}")

# %%
#for simple tree representation 
for i in range(5):
    print(tree.export_text(clf.estimators_[i]))
# Out:
# |--- feature_3 <= 0.70
# |   |--- class: 0.0
# |--- feature_3 >  0.70
# |   |--- feature_2 <= 4.85
# |   |   |--- class: 1.0
# |   |--- feature_2 >  4.85
# |   |   |--- feature_3 <= 1.75
# |   |   |   |--- feature_2 <= 5.30
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- feature_2 >  5.30
# |   |   |   |   |--- class: 2.0
# |   |   |--- feature_3 >  1.75
# |   |   |   |--- class: 2.0
#
# |--- feature_0 <= 5.05
# |   |--- feature_3 <= 0.80
# |   |   |--- class: 0.0
# |   |--- feature_3 >  0.80
# |   |   |--- class: 1.0
# |--- feature_0 >  5.05
# |   |--- feature_0 <= 6.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_2 <= 2.35
# |   |   |   |   |--- class: 0.0
# |   |   |   |--- feature_2 >  2.35
# |   |   |   |   |--- feature_0 <= 6.15
# |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |--- feature_0 >  6.15
# |   |   |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |--- feature_3 >  1.65
# ...
